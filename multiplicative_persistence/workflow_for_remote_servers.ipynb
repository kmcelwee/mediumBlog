# %%
import pickle
import json
import time

# %%
def stringify(num):
    l = [0]*10

    if type(num) == int:
        s = str(num)
        for c in s:
            l[int(c)] += 1
    if type(num) == list:
        for c in num:
            l[c] += 1

    return ','.join([str(i) for i in l[2:]])

def expand_dict(d, beg, end):
    # seven added shapes to a cube
    # cube: 2, 3, 7
    
    # expanded_cube:
    for t in range(beg, end):
        tp = 2**t
        for th in range(beg, end):
            thp = 3**th
            for s in range(beg, end):
                sp = 7**s
                num = tp*thp*sp
                if '0' not in str(num):
                    string = stringify(num)
                    d[string] = d.get(string, []) + [num]
    
    # dim-longs
    # 7
    for t in range(beg, end):
        tp = 2**t
        for th in range(beg, end):
            thp = 3**th
            for s in range(0, beg):
                sp = 7**s
                num = tp*thp*sp
                if '0' not in str(num):
                    string = stringify(num)
                    d[string] = d.get(string, []) + [num]
    
    # 2
    for t in range(0, beg):
        tp = 2**t
        for th in range(beg, end):
            thp = 3**th
            for s in range(beg, end):
                sp = 7**s
                num = tp*thp*sp
                if '0' not in str(num):
                    string = stringify(num)
                    d[string] = d.get(string, []) + [num]
    
    # 3             
    for t in range(beg, end):
        tp = 2**t
        for th in range(0, beg):
            thp = 3**th
            for s in range(beg, end):
                sp = 7**s
                num = tp*thp*sp
                if '0' not in str(num):
                    string = stringify(num)
                    d[string] = d.get(string, []) + [num]
    
    #faces
    # 2
    for t in range(beg, end):
        tp = 2**t
        for th in range(0, beg):
            thp = 3**th
            for s in range(0, beg):
                sp = 7**s
                num = tp*thp*sp
                if '0' not in str(num):
                    string = stringify(num)
                    d[string] = d.get(string, []) + [num]
                    
    # 3
    for t in range(0, beg):
        tp = 2**t
        for th in range(beg, end):
            thp = 3**th
            for s in range(0, beg):
                sp = 7**s
                num = tp*thp*sp
                if '0' not in str(num):
                    string = stringify(num)
                    d[string] = d.get(string, []) + [num]
    # 7
    for t in range(0, beg):
        tp = 2**t
        for th in range(0, beg):
            thp = 3**th
            for s in range(beg, end):
                sp = 7**s
                num = tp*thp*sp
                if '0' not in str(num):
                    string = stringify(num)
                    d[string] = d.get(string, []) + [num]
     
# --------------------------------------------------------------------------------------------------- #
# cube: 5, 3, 7
#     print('fives')
    beg_p = 1 if beg == 0 else beg
    
    # expanded_cube:
    for t in range(beg_p, end):
        tp = 5**t
        for th in range(beg, end):
            thp = 3**th
            for s in range(beg, end):
                sp = 7**s
                num = tp*thp*sp
                if '0' not in str(num):
                    string = stringify(num)
                    d[string] = d.get(string, []) + [num]
    
    # dim-longs
    # 7
    for t in range(beg_p, end):
        tp = 5**t
        for th in range(beg, end):
            thp = 3**th
            for s in range(0, beg):
                sp = 7**s
                num = tp*thp*sp
                if '0' not in str(num):
                    string = stringify(num)
                    d[string] = d.get(string, []) + [num]
    
    # 2
    for t in range(1, beg):
        tp = 5**t
        for th in range(beg, end):
            thp = 3**th
            for s in range(beg, end):
                sp = 7**s
                num = tp*thp*sp
                if '0' not in str(num):
                    string = stringify(num)
                    d[string] = d.get(string, []) + [num]
    
    # 3             
    for t in range(beg_p, end):
        tp = 5**t
        for th in range(0, beg):
            thp = 3**th
            for s in range(beg, end):
                sp = 7**s
                num = tp*thp*sp
                if '0' not in str(num):
                    string = stringify(num)
                    d[string] = d.get(string, []) + [num]
    
    #faces
    # 2
    for t in range(beg_p, end):
        tp = 5**t
        for th in range(0, beg):
            thp = 3**th
            for s in range(0, beg):
                sp = 7**s
                num = tp*thp*sp
                if '0' not in str(num):
                    string = stringify(num)
                    d[string] = d.get(string, []) + [num]
                    
    # 3
    for t in range(1, beg):
        tp = 5**t
        for th in range(beg, end):
            thp = 3**th
            for s in range(0, beg):
                sp = 7**s
                num = tp*thp*sp
                if '0' not in str(num):
                    string = stringify(num)
                    d[string] = d.get(string, []) + [num]
    # 7
    for t in range(1, beg):
        tp = 5**t
        for th in range(0, beg):
            thp = 3**th
            for s in range(beg, end):
                sp = 7**s
                num = tp*thp*sp
                if '0' not in str(num):
                    string = stringify(num)
                    d[string] = d.get(string, []) + [num]

    with open('dict' + str(end) + '.pickle', 'wb') as f:
        pickle.dump(d, f)
    
    return d

# %%
# CHOOSE BEGINNING AND END

beg = 650
end = 670
old = 'dict650.pickle'

with open(old, 'rb') as f:
    d_o = pickle.load(f)

tic = time.time()
d_n = expand_dict(d_o, beg, end)
print(tic-time.time())
